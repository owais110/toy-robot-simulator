# %%
def test_robot():
    # Let's set up some commands to see how our robot behaves
    commands = [
        "PLACE 0,0,NORTH",  # Start at the bottom-left corner, facing up
        "MOVE",             # Move one step forward
        "REPORT",           # Should be at 0,1 facing NORTH
        "LEFT",             # Turn left to face WEST
        "REPORT",           # Should now be 0,1 facing WEST
        "MOVE",             # Try to move left, but we're at the edge
        "REPORT",           # Still at 0,1 facing WEST
        "RIGHT",            # Turn right to face NORTH again
        "MOVE",             # Move forward to 1,1
        "REPORT",           # Should be at 1,1 facing NORTH
        "PLACE 4,4,EAST",   # Jump to the top-right corner, facing right
        "MOVE",             # Try to move right, but can't go further
        "REPORT",           # Should be at 4,4 facing EAST
        "LEFT",             # Turn left to face NORTH
        "MOVE",             # Move forward to 4,3
        "REPORT"            # Should be at 4,3 facing NORTH
    ]

    # Run the commands through our robot
    process_commands(commands)

test_robot()
